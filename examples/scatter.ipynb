# %%
from examples.sample_datasource import SampleDatasource
from footballdashboards.dashboard.scatterdashboard import ScatterDashboard, ScatterTexts, ScatterWithQuadrantsDashboard, ScatterWithRegressionDashboard, Dashboard

# %%
dashboard = ScatterWithQuadrantsDashboard(
    SampleDatasource(), 
    x_column="Turnovers Per 100 Touches",
    y_column="Shots Created Per 100 Touches", 
    texts=ScatterTexts(title='Creating Shots, But At What Cost?', subtitle='Shot creation and possession loss on a per touch basis', explanatory_text="Some explanatory text here")
)
dashboard.bottom_boundary_multiplier = 1.2
dashboard.name_annotation_threshold = 0.1
dashboard.quadrant_texts = {
    'topright': 'High Shot Creation, Low Possession Loss',
    'topleft': 'Low Shot Creation, Low Possession Loss',
    'bottomright': 'High Shot Creation, High Possession Loss',
    'bottomleft': 'Low Shot Creation, High Possession Loss'
}
dashboard.top_boundary_multiplier = 1.2

# %%
dashboard.plot_seasons_leagues(seasons=2022, leagues=['Premier League','Serie A','Bundesliga','La Liga','Ligue 1','Primeira Liga','Eredivisie'])
# Out:
# c:\Users\dmitr\python\footballdashboards\env\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# c:\Users\dmitr\python\footballdashboards\env\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# (<Figure size 1400x1540 with 3 Axes>,
#  {'title': <AxesSubplot: >,
#   'scatter': <AxesSubplot: xlabel='Turnovers Per 100 Touches', ylabel='Shots Created Per 100 Touches'>,
#   'endnote': <AxesSubplot: >})

# %%
dashboard.describe_adjustable_fields()
# Out:
# {'mean_line_color': 'Color of the line separating the quadrants. Current value: ivory',
#  'top_right_quadrant_color': 'Color of the top right quadrant. Current value: green',
#  'top_left_quadrant_color': 'Color of the top left quadrant. Current value: yellow',
#  'bottom_right_quadrant_color': 'Color of the bottom right quadrant. Current value: yellow',
#  'bottom_left_quadrant_color': 'Color of the bottom left quadrant. Current value: red',
#  'quadrant_texts': "Texts to be displayed in the quadrants. Current value: {'topright': 'High Shot Creation, Low Possession Loss', 'topleft': 'Low Shot Creation, Low Possession Loss', 'bottomright': 'High Shot Creation, High Possession Loss', 'bottomleft': 'Low Shot Creation, High Possession Loss'}",
#  'figsize': 'Figsize in centimeters, must be tuple (x, y). Current value: (14, 15.4)',
#  'title_font_size': 'Title font size in pts. Current value: 24',
#  'subtitle_font_size': 'Subtitle font size in pts. Current value: 18',
# ...

# %%
dashboard = ScatterWithRegressionDashboard(
    SampleDatasource(), 
    x_column="Turnovers Per 100 Touches",
    y_column="Shots Created Per 100 Touches", 
    texts=ScatterTexts(title='Creating Shots, But At What Cost?', subtitle='Shot creation and possession loss on a per touch basis')
)
dashboard.name_annotation_threshold = 0.1
dashboard.regression_annotation_texts = {
    
    'topleft': 'More shot creation compared to possession lost',
    'bottomright': 'More possession lost compared to shot creation',
}

# %%
dashboard.plot_seasons_leagues(seasons=2022, leagues=['Premier League','Serie A','Bundesliga','La Liga','Ligue 1','Primeira Liga','Eredivisie'])
# Out:
# c:\Users\dmitr\python\footballdashboards\env\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# c:\Users\dmitr\python\footballdashboards\env\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# (<Figure size 1400x1540 with 3 Axes>,
#  array([<AxesSubplot: >,
#         <AxesSubplot: xlabel='Turnovers Per 100 Touches', ylabel='Shots Created Per 100 Touches'>,
#         <AxesSubplot: >], dtype=object))
